# %%
import requests
from bs4 import BeautifulSoup
import os
import glob
import pandas as pd
import numpy as np

# %%
url = 'https://webrobots.io/kickstarter-datasets/'
response = requests.get(url)
page = response.text

# %%
soup = BeautifulSoup(page,"html5lib")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-overflow-y" lang="en-US" prefix="" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Kickstarter Datasets – Web Scraping Service
#   </title>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://webrobots.io/feed/" rel="alternate" title="Web Scraping Service » Feed" type="application/rss+xml"/>
#   <link href="https://webrobots.io/comments/feed/" rel="alternate" title="Web Scraping Service » Comments Feed" type="application/rss+xml"/>
#   <link href="/wp-content/uploads/2015/03/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!-- For iPhone -->
#   <link href="/wp-content/uploads/2015/03/WebRobotsLogo57x57.png" rel="apple-touch-icon"/>
# ...

# %%
links = soup.find_all('a',text='CSV')

# %%
links
# Out:
# [<a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-07-15T22_20_48_951Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-06-15T22_20_03_059Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-05-15T22_21_11_300Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-04-15T22_21_18_122Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-03-15T22_20_55_874Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-02-15T22_22_48_377Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-01-15T22_21_04_985Z.zip">CSV</a>,
#  <a href="https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-12-15T22_20_52_411Z.zip">CSV</a>,
# ...

# %%
ks = pd.read_csv('/home/bf2398/Documents/Kickstarter001.csv')

# %%
# !wget {links[0]['href']} -P /home/bf2398/Metis/projects/04-fletcher/files
# Out:
# --2017-08-14 18:09:21--  https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2017-07-15T22_20_48_951Z.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.83.75
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.83.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146774488 (140M) [application/zip]
# Saving to: ‘/home/bf2398/Metis/projects/04-fletcher/files/Kickstarter_2017-07-15T22_20_48_951Z.zip’
#
# Kickstarter_2017-07 100%[===================>] 139.97M  4.89MB/s    in 36s
#
# 2017-08-14 18:09:58 (3.84 MB/s) - ‘/home/bf2398/Metis/projects/04-fletcher/files/Kickstarter_2017-07-15T22_20_48_951Z.zip’ saved [146774488/146774488]

# %%
for name in glob.glob('/home/bf2398/Metis/projects/04-fletcher/files/*.zip'):
    # !unzip {name} -d /home/bf2398/Metis/projects/04-fletcher/files/
# Out:
# Archive:  /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter_2017-07-15T22_20_48_951Z.zip
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter026.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter010.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter040.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter012.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter002.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter041.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter023.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter045.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter006.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter003.csv
#   inflating: /home/bf2398/Metis/projects/04-fletcher/files/Kickstarter011.csv
# ...

# %%
for name in glob.glob('/home/bf2398/Metis/projects/04-fletcher/files/*.csv'):
    temp = pd.read_csv(name)
    ks = pd.concat([ks, temp])

# %%
ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200881 entries, 0 to 4090
# Data columns (total 32 columns):
# id                        200881 non-null int64
# photo                     200881 non-null object
# name                      200879 non-null object
# blurb                     200867 non-null object
# goal                      200881 non-null float64
# pledged                   200881 non-null float64
# state                     200881 non-null object
# slug                      200881 non-null object
# disable_communication     200881 non-null bool
# country                   200881 non-null object
# currency                  200881 non-null object
# currency_symbol           200881 non-null object
# currency_trailing_code    200881 non-null bool
# deadline                  200881 non-null int64
# state_changed_at          200881 non-null int64
# created_at                200881 non-null int64
# launched_at               200881 non-null int64
# ...
